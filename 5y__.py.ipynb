# %%
import networkx as nx
from cpn import G

#print(G)
cpnx = nx.MultiDiGraph(G)
#print (cpnx.nodes())
#print (cpnx.edges())

print("Number of nodes is:", cpnx.number_of_nodes())
print("Number of edges is:", cpnx.number_of_edges())

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline


plt.subplot(121)
nx.draw(cpnx, with_labels = True, font_weight = 'bold')
plt.subplot(122)
nx.draw_shell(cpnx, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
plt.show()
# Out:
# Number of nodes is: 251
# Number of edges is: 992
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     393     try:
# --> 394         xy = np.asarray([pos[v] for v in nodelist])
#     395     except KeyError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in <listcomp>(.0)
#     393     try:
# --> 394         xy = np.asarray([pos[v] for v in nodelist])
#     395     except KeyError as e:
#
# KeyError: '3RD90PSK03'
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-4-671b815e5024> in <module>
#      19 nx.draw(cpnx, with_labels = True, font_weight = 'bold')
#      20 plt.subplot(122)
# ---> 21 nx.draw_shell(cpnx, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
#      22 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_shell(G, **kwargs)
#    1054     if nlist is not None:
#    1055         del(kwargs['nlist'])
# -> 1056     draw(G, shell_layout(G, nlist=nlist), **kwargs)
#    1057
#    1058
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     124
#     125     try:
# --> 126         draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127         ax.set_axis_off()
#     128         plt.draw_if_interactive()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     275         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     276
# --> 277     node_collection = draw_networkx_nodes(G, pos, **kwds)
#     278     edge_collection = draw_networkx_edges(G, pos, arrows=arrows, **kwds)
#     279     if with_labels:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     394         xy = np.asarray([pos[v] for v in nodelist])
#     395     except KeyError as e:
# --> 396         raise nx.NetworkXError('Node %s has no position.' % e)
#     397     except ValueError:
#     398         raise nx.NetworkXError('Bad value in node positions.')
#
# NetworkXError: Node '3RD90PSK03' has no position.

# %%
path_length_x = nx.single_source_shortest_path("PE90TZL23", "PE90ADN03_9K")
print(path_length_x)
# Out:
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# <ipython-input-17-e32a2509a181> in <module>
# ----> 1 path_length_x = nx.single_source_shortest_path("PE90TZL23", "PE90ADN03_9K")
#       2 print(path_length_x)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/algorithms/shortest_paths/unweighted.py in single_source_shortest_path(G, source, cutoff)
#     333     """
#     334     if source not in G:
# --> 335         raise nx.NodeNotFound("Source {} not in G".format(source))
#     336
#     337     def join(p1, p2):
#
# NodeNotFound: Source PE90ADN03_9K not in G
